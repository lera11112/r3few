# %% [markdown]
# # Метод Apriori ассоциативного анализа
#
# Написанного Ю Мочизуки (Yu Mochizuki)
# Устанавливаем
#
# ```
# pip install apyori
# copy apyori.py into your project.
# python setup.py install
# ```

# %%
import pandas as pd

# Данные https://www.kaggle.com/datasets/devchauhan1/market-basket-optimisationcsv
dataset = pd.read_csv("./data/Market_Basket_Optimisation.csv", header=None)
dataset.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %% [markdown]
# ### Очистка данных

# %%
dataset.fillna(method="ffill", axis=1, inplace=True)
dataset.head()
# Out:
# /tmp/ipykernel_8230/2620673325.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method="ffill", axis=1, inplace=True)
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs              eggs          eggs
# 2        chutney    chutney     chutney           chutney       chutney
# 3         turkey    avocado     avocado           avocado       avocado
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5          6               7             8             9   \
# 0  whole weat flour       yams  cottage cheese  energy drink  tomato juice
# 1              eggs       eggs            eggs          eggs          eggs
# 2           chutney    chutney         chutney       chutney       chutney
# 3           avocado    avocado         avocado       avocado       avocado
# 4         green tea  green tea       green tea     green tea     green tea
#
#                10         11         12         13             14         15  \
# 0  low fat yogurt  green tea      honey      salad  mineral water     salmon
# 1            eggs       eggs       eggs       eggs           eggs       eggs
# 2         chutney    chutney    chutney    chutney        chutney    chutney
# 3         avocado    avocado    avocado    avocado        avocado    avocado
# 4       green tea  green tea  green tea  green tea      green tea  green tea
#
#                   16               17         18         19
# 0  antioxydant juice  frozen smoothie    spinach  olive oil
# 1               eggs             eggs       eggs       eggs
# 2            chutney          chutney    chutney    chutney
# 3            avocado          avocado    avocado    avocado
# 4          green tea        green tea  green tea  green tea

# %%
from apyori import apriori

# создадим из них матрицу
transactions = []
for i in range(0, 7501):
    transactions.append([str(dataset.values[i, j]) for j in range(0, 20)])
""" 
и обучимся правилам. Обратите внимание, что пороговые значения мы выбираем сами в зависимости от того,
насколько "сильные" правила мы хотим получить
min_support -- минимальный support для правил (dtype = float).
min_confidence -- минимальное значение confidence для правил (dtype = float)
min_lift -- минимальный lift (dtype = float)
max_length -- максимальная длина itemset (вспоминаем про k-itemset)  (dtype = integer) 
"""
result = list(
    apriori(
        transactions, min_support=0.003, min_confidence=0.2, min_lift=4, min_length=2
    )
)
apriori
# Out:
# <function apyori.apriori(transactions, **kwargs)>

# %%
transactions
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers',
#   'meatballs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs'],
#  ['chutney',
#   'chutney',
#   'chutney',
#   'chutney',
#   'chutney',
#   'chutney',
#   'chutney',
#   'chutney',
#   'chutney',
#   'chutney',
#   'chutney',
#   'chutney',
#   'chutney',
#   'chutney',
#   'chutney',
#   'chutney',
#   'chutney',
#   'chutney',
#   'chutney',
#   'chutney'],
#  ['turkey',
#   'avocado',
#   'avocado',
#   'avocado',
#   'avocado',
#   'avocado',
#   'avocado',
#   'avocado',
#   'avocado',
#   'avocado',
#   'avocado',
#   'avocado',
#   'avocado',
#   'avocado',
#   'avocado',
#   'avocado',
#   'avocado',
#   'avocado',
#   'avocado',
#   'avocado'],
#  ['mineral water',
#   'milk',
#   'energy bar',
#   'whole wheat rice',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt'],
#  ['whole wheat pasta',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries'],
#  ['soup',
#   'light cream',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot'],
#  ['frozen vegetables',
#   'spaghetti',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries'],
#  ['eggs',
#   'pet food',
#   'pet food',
#   'pet food',
#   'pet food',
#   'pet food',
#   'pet food',
#   'pet food',
#   'pet food',
#   'pet food',
#   'pet food',
#   'pet food',
#   'pet food',
#   'pet food',
#   'pet food',
#   'pet food',
#   'pet food',
#   'pet food',
#   'pet food',
#   'pet food'],
#  ['cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies'],
#  ['turkey',
#   'burgers',
#   'mineral water',
#   'eggs',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil'],
#  ['spaghetti',
#   'champagne',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies'],
#  ['mineral water',
#   'salmon',
#   'salmon',
#   'salmon',
#   'salmon',
#   'salmon',
#   'salmon',
#   'salmon',
#   'salmon',
#   'salmon',
#   'salmon',
#   'salmon',
#   'salmon',
#   'salmon',
#   'salmon',
#   'salmon',
#   'salmon',
#   'salmon',
#   'salmon',
#   'salmon'],
#  ['mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water'],
#  ['shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt'],
#  ['turkey',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs'],
#  ['turkey',
#   'fresh tuna',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'black tea',
#   'salmon',
#   'eggs',
#   'chicken',
#   'extra dark chocolate',
#   'extra dark chocolate',
#   'extra dark chocolate',
#   'extra dark chocolate',
#   'extra dark chocolate',
#   'extra dark chocolate',
#   'extra dark chocolate',
#   'extra dark chocolate',
#   'extra dark chocolate',
#   'extra dark chocolate',
#   'extra dark chocolate'],
#  ['meatballs',
#   'milk',
#   'honey',
#   'french fries',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar'],
#  ['red wine',
#   'shrimp',
#   'pasta',
#   'pepper',
#   'eggs',
#   'chocolate',
#   'shampoo',
#   'shampoo',
#   'shampoo',
#   'shampoo',
#   'shampoo',
#   'shampoo',
#   'shampoo',
#   'shampoo',
#   'shampoo',
#   'shampoo',
#   'shampoo',
#   'shampoo',
#   'shampoo',
#   'shampoo'],
#  ['rice',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water'],
#  ['spaghetti',
#   'mineral water',
#   'ham',
#   'body spray',
#   'pancakes',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['burgers',
#   'grated cheese',
#   'shrimp',
#   'pasta',
#   'avocado',
#   'honey',
#   'white wine',
#   'toothpaste',
#   'toothpaste',
#   'toothpaste',
#   'toothpaste',
#   'toothpaste',
#   'toothpaste',
#   'toothpaste',
#   'toothpaste',
#   'toothpaste',
#   'toothpaste',
#   'toothpaste',
#   'toothpaste',
#   'toothpaste'],
#  ['eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs'],
#  ['parmesan cheese',
#   'spaghetti',
#   'soup',
#   'avocado',
#   'milk',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread'],
#  ['ground beef',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'energy bar',
#   'black tea',
#   'salmon',
#   'frozen smoothie',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope'],
#  ['sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water'],
#  ['mineral water',
#   'eggs',
#   'chicken',
#   'chocolate',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries'],
#  ['frozen vegetables',
#   'spaghetti',
#   'yams',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water'],
#  ['herb & pepper',
#   'tomato sauce',
#   'light cream',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines'],
#  ['mineral water',
#   'chocolate',
#   'avocado',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs'],
#  ['turkey',
#   'french fries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries'],
#  ['frozen vegetables',
#   'strong cheese',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate'],
#  ['cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies'],
#  ['pickles',
#   'spaghetti',
#   'salmon',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope'],
#  ['energy bar',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries'],
#  ['red wine',
#   'ground beef',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water',
#   'mineral water'],
#  ['mineral water',
#   'cake',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese'],
#  ['pickles',
#   'champagne',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti'],
#  ['fresh tuna',
#   'frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'honey',
#   'whole wheat rice',
#   'frozen smoothie',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope'],
#  ['spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti'],
#  ['soup',
#   'meatballs',
#   'hot dogs',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water',
#   'sparkling water'],
#  ['escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope'],
#  ['soup',
#   'avocado',
#   'french fries',
#   'hot dogs',
#   'brownies',
#   'body spray',
#   'pancakes',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['mineral water',
#   'chicken',
#   'cereals',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories'],
#  ['mineral water',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray'],
#  ['avocado',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins'],
#  ['burgers',
#   'black tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['spaghetti',
#   'chocolate',
#   'brownies',
#   'white wine',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['fresh tuna',
#   'mineral water',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs'],
#  ['spaghetti',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins'],
#  ['spaghetti',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate'],
#  ['french fries',
#   'escalope',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne'],
#  ['tomato sauce',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo'],
#  ['turkey',
#   'fresh tuna',
#   'frozen vegetables',
#   'tomatoes',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'soup',
#   'milk',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil'],
#  ['eggs',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies'],
#  ['soup',
#   'chicken',
#   'gums',
#   'soda',
#   'body spray',
#   'energy drink',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['turkey',
#   'frozen vegetables',
#   'mineral water',
#   'cider',
#   'cooking oil',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti'],
#  ['clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories',
#   'clothes accessories'],
#  ['energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink'],
#  ['soup',
#   'bug spray',
#   'shallot',
#   'protein bar',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['turkey',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs'],
#  ['french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries'],
#  ['chocolate',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk'],
#  ['herb & pepper',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'avocado',
#   'cider',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice'],
#  ['cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies'],
#  ['shrimp',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta'],
#  ['grated cheese',
#   'herb & pepper',
#   'tomatoes',
#   'tomato sauce',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn'],
#  ['burgers',
#   'escalope',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot'],
#  ['cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies'],
#  ['yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake'],
#  ['soup',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs'],
#  ['cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies'],
#  ['mineral water',
#   'chocolate',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt'],
#  ['eggs',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries'],
#  ['grated cheese',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'white wine',
#   'white wine',
#   'white wine',
#   'white wine',
#   'white wine',
#   'white wine',
#   'white wine',
#   'white wine',
#   'white wine',
#   'white wine',
#   'white wine',
#   'white wine',
#   'white wine',
#   'white wine',
#   'white wine',
#   'white wine'],
#  ['mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint'],
#  ['eggs',
#   'cake',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries'],
#  ['burgers',
#   'spaghetti',
#   'milk',
#   'french fries',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['mineral water',
#   'energy bar',
#   'butter',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries'],
#  ['burgers',
#   'grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'eggs',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil'],
#  ['energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar'],
#  ['energy bar',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink'],
#  ['chocolate',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie'],
#  ['low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt'],
#  ['asparagus',
#   'salad',
#   'salad',
#   'salad',
#   'salad',
#   'salad',
#   'salad',
#   'salad',
#   'salad',
#   'salad',
#   'salad',
#   'salad',
#   'salad',
#   'salad',
#   'salad',
#   'salad',
#   'salad',
#   'salad',
#   'salad',
#   'salad'],
#  ['burgers',
#   'french fries',
#   'low fat yogurt',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt'],
#  ['burgers',
#   'herb & pepper',
#   'shrimp',
#   'pasta',
#   'spaghetti',
#   'mineral water',
#   'meatballs',
#   'olive oil',
#   'energy bar',
#   'french wine',
#   'eggs',
#   'salt',
#   'salt',
#   'salt',
#   'salt',
#   'salt',
#   'salt',
#   'salt',
#   'salt',
#   'salt'],
#  ['champagne',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt'],
#  ['champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne'],
#  ['burgers',
#   'almonds',
#   'eggs',
#   'french fries',
#   'cookies',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['ham',
#   'soup',
#   'escalope',
#   'body spray',
#   'body spray',
#   'body spray',
#   'body spray',
#   'body spray',
#   'body spray',
#   'body spray',
#   'body spray',
#   'body spray',
#   'body spray',
#   'body spray',
#   'body spray',
#   'body spray',
#   'body spray',
#   'body spray',
#   'body spray',
#   'body spray'],
#  ['turkey',
#   'ham',
#   'frozen vegetables',
#   'pepper',
#   'oil',
#   'extra dark chocolate',
#   'tea',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines',
#   'magazines'],
#  ['muffins',
#   'eggs',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies'],
#  ['cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies'],
#  ['frozen vegetables',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'chocolate',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['mineral water',
#   'barbecue sauce',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate'],
#  ['burgers',
#   'herb & pepper',
#   'energy bar',
#   'almonds',
#   'eggs',
#   'corn',
#   'mayonnaise',
#   'zucchini',
#   'zucchini',
#   'zucchini',
#   'zucchini',
#   'zucchini',
#   'zucchini',
#   'zucchini',
#   'zucchini',
#   'zucchini',
#   'zucchini',
#   'zucchini',
#   'zucchini',
#   'zucchini'],
#  ['turkey',
#   'burgers',
#   'ground beef',
#   'chocolate',
#   'soup',
#   'almonds',
#   'eggs',
#   'hot dogs',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese'],
#  ['ham',
#   'spaghetti',
#   'chocolate',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs'],
#  ['ground beef',
#   'energy bar',
#   'pet food',
#   'carrots',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar'],
#  ['ground beef',
#   'tomato sauce',
#   'spaghetti',
#   'mineral water',
#   'almonds',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs'],
#  ['mineral water',
#   'olive oil',
#   'gums',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil',
#   'cooking oil'],
#  ['shrimp',
#   'pasta',
#   'mineral water',
#   'soup',
#   'avocado',
#   'milk',
#   'olive oil',
#   'green grapes',
#   'eggs',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray',
#   'bug spray'],
#  ['shrimp',
#   'pasta',
#   'soup',
#   'cake',
#   'cooking oil',
#   'chicken',
#   'light mayo',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt'],
#  ['spaghetti',
#   'mineral water',
#   'chocolate',
#   'french fries',
#   'champagne',
#   'escalope',
#   'mushroom cream sauce',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread'],
#  ['shrimp',
#   'pasta',
#   'mineral water',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs'],
#  ['burgers',
#   'oil',
#   'tomato juice',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread'],
#  ['french wine',
#   'eggs',
#   'chocolate',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt'],
#  ['chicken',
#   'eggs',
#   'french fries',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes'],
#  ['turkey',
#   'herb & pepper',
#   'salmon',
#   'white wine',
#   'candy bars',
#   'candy bars',
#   'candy bars',
#   'candy bars',
#   'candy bars',
#   'candy bars',
#   'candy bars',
#   'candy bars',
#   'candy bars',
#   'candy bars',
#   'candy bars',
#   'candy bars',
#   'candy bars',
#   'candy bars',
#   'candy bars',
#   'candy bars'],
#  ['grated cheese',
#   'spaghetti',
#   'olive oil',
#   'eggs',
#   'french fries',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['mineral water',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar',
#   'energy bar'],
#  ['eggs',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries'],
#  ['burgers',
#   'tomatoes',
#   'mineral water',
#   'soup',
#   'milk',
#   'almonds',
#   'eggs',
#   'chocolate',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice'],
#  ['muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins',
#   'muffins'],
#  ['pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta',
#   'pasta'],
#  ['tomatoes',
#   'spaghetti',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie'],
#  ['ground beef',
#   'spaghetti',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk'],
#  ['french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries'],
#  ['chocolate',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk'],
#  ['burgers',
#   'shrimp',
#   'pasta',
#   'frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'eggs',
#   'chocolate',
#   'french fries',
#   'pancakes',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt'],
#  ['ground beef',
#   'mineral water',
#   'antioxydant juice',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar',
#   'protein bar'],
#  ['grated cheese',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'cake',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink',
#   'energy drink'],
#  ['grated cheese',
#   'grated cheese',
#   'grated cheese',
#   'grated cheese',
#   'grated cheese',
#   'grated cheese',
#   'grated cheese',
#   'grated cheese',
#   'grated cheese',
#   'grated cheese',
#   'grated cheese',
#   'grated cheese',
#   'grated cheese',
#   'grated cheese',
#   'grated cheese',
#   'grated cheese',
#   'grated cheese',
#   'grated cheese',
#   'grated cheese',
#   'grated cheese'],
#  ['pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes'],
#  ['frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie'],
#  ['carrots',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate'],
#  ['turkey',
#   'burgers',
#   'chocolate',
#   'olive oil',
#   'eggs',
#   'cooking oil',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn',
#   'corn'],
#  ['frozen vegetables',
#   'tomatoes',
#   'pepper',
#   'spaghetti',
#   'mineral water',
#   'pancakes',
#   'chicken',
#   'chili',
#   'tea',
#   'french fries',
#   'tomato juice',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread'],
#  ['cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies'],
#  ['ground beef',
#   'ground beef',
#   'ground beef',
#   'ground beef',
#   'ground beef',
#   'ground beef',
#   'ground beef',
#   'ground beef',
#   'ground beef',
#   'ground beef',
#   'ground beef',
#   'ground beef',
#   'ground beef',
#   'ground beef',
#   'ground beef',
#   'ground beef',
#   'ground beef',
#   'ground beef',
#   'ground beef',
#   'ground beef'],
#  ['turkey',
#   'eggs',
#   'chocolate',
#   'frozen smoothie',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice'],
#  ['frozen vegetables',
#   'cooking oil',
#   'mashed potato',
#   'mashed potato',
#   'mashed potato',
#   'mashed potato',
#   'mashed potato',
#   'mashed potato',
#   'mashed potato',
#   'mashed potato',
#   'mashed potato',
#   'mashed potato',
#   'mashed potato',
#   'mashed potato',
#   'mashed potato',
#   'mashed potato',
#   'mashed potato',
#   'mashed potato',
#   'mashed potato',
#   'mashed potato'],
#  ['frozen vegetables',
#   'ground beef',
#   'tomato sauce',
#   'mineral water',
#   'meatballs',
#   'olive oil',
#   'light cream',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice'],
#  ['red wine',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'milk',
#   'eggs',
#   'cake',
#   'gums',
#   'cooking oil',
#   'chocolate',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie'],
#  ['chocolate',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'avocado',
#   'milk',
#   'olive oil',
#   'eggs',
#   'rice',
#   'french fries',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies'],
#  ['chocolate',
#   'shrimp',
#   'pasta',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'nonfat milk',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs'],
#  ['turkey',
#   'shrimp',
#   'pasta',
#   'pepper',
#   'spaghetti',
#   'mineral water',
#   'eggs',
#   'chicken',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries'],
#  ['cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies'],
#  ['turkey',
#   'tomatoes',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake'],
#  ['yams',
#   'mineral water',
#   'soup',
#   'milk',
#   'pancakes',
#   'whole wheat rice',
#   'barbecue sauce',
#   'carrots',
#   'chocolate',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne'],
#  ['rice',
#   'rice',
#   'rice',
#   'rice',
#   'rice',
#   'rice',
#   'rice',
#   'rice',
#   'rice',
#   'rice',
#   'rice',
#   'rice',
#   'rice',
#   'rice',
#   'rice',
#   'rice',
#   'rice',
#   'rice',
#   'rice',
#   'rice'],
#  ['chocolate',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk',
#   'milk'],
#  ['shrimp',
#   'pasta',
#   'frozen vegetables',
#   'water spray',
#   'water spray',
#   'water spray',
#   'water spray',
#   'water spray',
#   'water spray',
#   'water spray',
#   'water spray',
#   'water spray',
#   'water spray',
#   'water spray',
#   'water spray',
#   'water spray',
#   'water spray',
#   'water spray',
#   'water spray',
#   'water spray'],
#  ['burgers',
#   'mineral water',
#   'milk',
#   'eggs',
#   'whole wheat rice',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint'],
#  ['mineral water',
#   'vegetables mix',
#   'cake',
#   'frozen smoothie',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies',
#   'brownies'],
#  ['cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies'],
#  ['shrimp',
#   'pasta',
#   'chicken',
#   'chocolate bread',
#   'chocolate bread',
#   'chocolate bread',
#   'chocolate bread',
#   'chocolate bread',
#   'chocolate bread',
#   'chocolate bread',
#   'chocolate bread',
#   'chocolate bread',
#   'chocolate bread',
#   'chocolate bread',
#   'chocolate bread',
#   'chocolate bread',
#   'chocolate bread',
#   'chocolate bread',
#   'chocolate bread',
#   'chocolate bread'],
#  ['shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot',
#   'shallot'],
#  ['shrimp',
#   'pasta',
#   'spaghetti',
#   'eggs',
#   'hot dogs',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['burgers',
#   'burgers',
#   'burgers',
#   'burgers',
#   'burgers',
#   'burgers',
#   'burgers',
#   'burgers',
# ...
#   'honey',
#   'honey',
#   'honey',
#   'honey',
#   'honey',
#   'honey',
#   'honey',
#   'honey',
#   'honey',
#   'honey',
#   'honey',
#   'honey',
#   'honey',
#   'honey',
#   'honey',
#   'honey'],
#  ['shrimp',
#   'frozen vegetables',
#   'tomatoes',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese',
#   'cottage cheese'],
#  ['french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries'],
#  ['strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries'],
#  ['ground beef',
#   'almonds',
#   'french fries',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope'],
#  ['grated cheese',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti',
#   'spaghetti'],
#  ['turkey',
#   'mineral water',
#   'butter',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie'],
#  ['frozen vegetables',
#   'spaghetti',
#   'french fries',
#   'light mayo',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['burgers',
#   'ham',
#   'spaghetti',
#   'whole wheat rice',
#   'eggplant',
#   'chocolate',
#   'cookies',
#   'shallot',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['grated cheese',
#   'frozen vegetables',
#   'spaghetti',
#   'avocado',
#   'milk',
#   'blueberries',
#   'light cream',
#   'rice',
#   'green tea',
#   'chocolate',
#   'french fries',
#   'frozen smoothie',
#   'cookies',
#   'hot dogs',
#   'hot dogs',
#   'hot dogs',
#   'hot dogs',
#   'hot dogs',
#   'hot dogs',
#   'hot dogs'],
#  ['burgers',
#   'shrimp',
#   'tomatoes',
#   'bacon',
#   'whole wheat rice',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['parmesan cheese',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes'],
#  ['parmesan cheese',
#   'cake',
#   'hot dogs',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['spaghetti',
#   'milk',
#   'fromage blanc',
#   'ketchup',
#   'chocolate',
#   'babies food',
#   'babies food',
#   'babies food',
#   'babies food',
#   'babies food',
#   'babies food',
#   'babies food',
#   'babies food',
#   'babies food',
#   'babies food',
#   'babies food',
#   'babies food',
#   'babies food',
#   'babies food',
#   'babies food'],
#  ['mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint'],
#  ['chocolate',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint'],
#  ['butter',
#   'french fries',
#   'salt',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread',
#   'fresh bread'],
#  ['chocolate',
#   'french fries',
#   'strawberries',
#   'yogurt cake',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo',
#   'light mayo'],
#  ['eggs',
#   'eggplant',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies'],
#  ['yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake',
#   'yogurt cake'],
#  ['herb & pepper',
#   'spaghetti',
#   'meatballs',
#   'milk',
#   'olive oil',
#   'chicken',
#   'honey',
#   'frozen smoothie',
#   'escalope',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes'],
#  ['frozen vegetables',
#   'rice',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate'],
#  ['herb & pepper',
#   'ground beef',
#   'spaghetti',
#   'chocolate',
#   'milk',
#   'eggs',
#   'light cream',
#   'light cream',
#   'light cream',
#   'light cream',
#   'light cream',
#   'light cream',
#   'light cream',
#   'light cream',
#   'light cream',
#   'light cream',
#   'light cream',
#   'light cream',
#   'light cream',
#   'light cream'],
#  ['eggs',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne',
#   'champagne'],
#  ['whole wheat pasta',
#   'ground beef',
#   'olive oil',
#   'blueberries',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope',
#   'escalope'],
#  ['burgers',
#   'red wine',
#   'mineral water',
#   'eggs',
#   'oil',
#   'carrots',
#   'hand protein bar',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice'],
#  ['chocolate',
#   'grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'soup',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil'],
#  ['burgers',
#   'shrimp',
#   'mineral water',
#   'chicken',
#   'fromage blanc',
#   'salmon',
#   'eggs',
#   'cake',
#   'frozen smoothie',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries'],
#  ['green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies'],
#  ['french fries',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies',
#   'cookies'],
#  ['milk',
#   'butter',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs',
#   'eggs'],
#  ['eggs',
#   'mushroom cream sauce',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt'],
#  ['eggs',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['mineral water',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice',
#   'whole wheat rice'],
#  ['shrimp',
#   'frozen vegetables',
#   'parmesan cheese',
#   'mineral water',
#   'whole wheat rice',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake',
#   'cake'],
#  ['whole wheat rice',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes'],
#  ['frozen vegetables',
#   'spaghetti',
#   'olive oil',
#   'butter',
#   'salmon',
#   'oil',
#   'cooking oil',
#   'frozen smoothie',
#   'cauliflower',
#   'cauliflower',
#   'cauliflower',
#   'cauliflower',
#   'cauliflower',
#   'cauliflower',
#   'cauliflower',
#   'cauliflower',
#   'cauliflower',
#   'cauliflower',
#   'cauliflower',
#   'cauliflower'],
#  ['green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['fresh tuna',
#   'eggs',
#   'escalope',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries',
#   'strawberries'],
#  ['spaghetti',
#   'soup',
#   'milk',
#   'carrots',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate'],
#  ['burgers',
#   'mineral water',
#   'soup',
#   'meatballs',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil',
#   'olive oil'],
#  ['grated cheese',
#   'mineral water',
#   'cooking oil',
#   'french fries',
#   'cookies',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt',
#   'low fat yogurt'],
#  ['shrimp',
#   'milk',
#   'olive oil',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries',
#   'french fries'],
#  ['frozen vegetables',
#   'mineral water',
#   'pancakes',
#   'cake',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice'],
#  ['spaghetti',
#   'milk',
#   'chicken',
#   'chicken',
#   'chicken',
#   'chicken',
#   'chicken',
#   'chicken',
#   'chicken',
#   'chicken',
#   'chicken',
#   'chicken',
#   'chicken',
#   'chicken',
#   'chicken',
#   'chicken',
#   'chicken',
#   'chicken',
#   'chicken',
#   'chicken'],
#  ['grated cheese',
#   'mineral water',
#   'chicken',
#   'french fries',
#   'cottage cheese',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes',
#   'pancakes'],
#  ['ground beef',
#   'mineral water',
#   'milk',
#   'eggs',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint',
#   'mint'],
#  ['shrimp',
#   'body spray',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea',
#   'green tea'],
#  ['frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie',
#   'frozen smoothie'],
#  ['herb & pepper',
#   'frozen vegetables',
#   'mineral water',
#   'muffins',
#   'cereals',
#   'cereals',
#   'cereals',
#   'cereals',
#   'cereals',
#   'cereals',
#   'cereals',
#   'cereals',
#   'cereals',
#   'cereals',
#   'cereals',
#   'cereals',
#   'cereals',
#   'cereals',
#   'cereals',
#   'cereals'],
#  ['turkey',
#   'tomatoes',
#   'spaghetti',
#   'milk',
#   'cider',
#   'eggs',
#   'honey',
#   'cake',
#   'green tea',
#   'french fries',
#   'brownies',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice',
#   'tomato juice'],
#  ...]

# %%
import shutil, os
from io import StringIO
from apyori import dump_as_json
from IPython.display import display, HTML
import json

output = []
for RelationRecord in result:
    o = StringIO()
    dump_as_json(RelationRecord, o)
    output.append(json.loads(o.getvalue()))
df = pd.DataFrame(output)
df.sort_values(by=["support"], ascending=False)
# Out:
#                                                 items   support  \
# 3                      [olive oil, whole wheat pasta]  0.007999
# 10            [ground beef, herb & pepper, spaghetti]  0.006399
# 1                                   [escalope, pasta]  0.005866
# 4                                     [pasta, shrimp]  0.005066
# 0                              [chicken, light cream]  0.004533
# 18  [frozen vegetables, ground beef, mineral water...  0.004399
# 8                  [eggs, ground beef, herb & pepper]  0.004133
# 7             [chocolate, ground beef, herb & pepper]  0.003999
# 14      [mineral water, olive oil, whole wheat pasta]  0.003866
# 17  [frozen vegetables, ground beef, milk, mineral...  0.003733
# 12                            [milk, olive oil, soup]  0.003600
# 21  [frozen vegetables, mineral water, shrimp, spa...  0.003333
# 19  [frozen vegetables, milk, mineral water, olive...  0.003333
# 2                              [fromage blanc, honey]  0.003333
# 15  [chocolate, frozen vegetables, mineral water, ...  0.003200
# 16  [frozen smoothie, milk, mineral water, spaghetti]  0.003200
# 9          [french fries, ground beef, herb & pepper]  0.003200
# 20     [frozen vegetables, milk, mineral water, soup]  0.003066
# 11             [ground beef, spaghetti, tomato sauce]  0.003066
# 13                             [milk, soup, tomatoes]  0.003066
# 6                   [cereals, ground beef, spaghetti]  0.003066
# 5                 [cake, frozen vegetables, tomatoes]  0.003066
# 22  [ground beef, mineral water, spaghetti, tomatoes]  0.003066
#
#                                    ordered_statistics
# 3   [{'items_base': ['whole wheat pasta'], 'items_...
# 10  [{'items_base': ['herb & pepper', 'spaghetti']...
# 1   [{'items_base': ['pasta'], 'items_add': ['esca...
# 4   [{'items_base': ['pasta'], 'items_add': ['shri...
# 0   [{'items_base': ['light cream'], 'items_add': ...
# 18  [{'items_base': ['frozen vegetables', 'ground ...
# 8   [{'items_base': ['eggs', 'ground beef'], 'item...
# 7   [{'items_base': ['chocolate', 'herb & pepper']...
# 14  [{'items_base': ['mineral water', 'whole wheat...
# 17  [{'items_base': ['frozen vegetables', 'ground ...
# 12  [{'items_base': ['milk', 'olive oil'], 'items_...
# 21  [{'items_base': ['mineral water', 'shrimp', 's...
# 19  [{'items_base': ['frozen vegetables', 'olive o...
# 2   [{'items_base': ['fromage blanc'], 'items_add'...
# 15  [{'items_base': ['chocolate', 'frozen vegetabl...
# 16  [{'items_base': ['frozen smoothie', 'spaghetti...
# 9   [{'items_base': ['french fries', 'ground beef'...
# 20  [{'items_base': ['frozen vegetables', 'soup'],...
# 11  [{'items_base': ['tomato sauce'], 'items_add':...
# 13  [{'items_base': ['milk', 'tomatoes'], 'items_a...
# 6   [{'items_base': ['cereals', 'spaghetti'], 'ite...
# 5   [{'items_base': ['cake', 'frozen vegetables'],...
# 22  [{'items_base': ['ground beef', 'tomatoes'], '...

# %% [markdown]
# ### Результат
#
# Видим сочетания:
#
# - оливковое масло, макароны из цельнозерновой муки [olive oil, whole wheat pasta],
# - говяжий фарш, зелень и перец, спагетти [ground beef, herb & pepper, spaghetti],
# - эскалоп, макароны [escalope, pasta]

# %% [markdown]
# ### Теоретическая часть
#
# - https://www.kdnuggets.com/2016/04/association-rules-apriori-algorithm-tutorial.html
# - https://stackabuse.com/association-rule-mining-via-apriori-algorithm-in-python/

# %% [markdown]
# # Эффективный вариант Apriori с использованием сокращения хэшей

# %%
""" 
Эффективный вариант Apriori с использованием сокращения хэшей
"""

from itertools import combinations

class HashTable:
    """Хэш-таблица для сокращения наборов данных."""
    
    def __init__(self, hash_table_size: int):
        """Инициализация хэш-таблицы заданного размера."""
        self.hash_table = [0] * hash_table_size

    def add_itemset(self, itemset):
        """Добавить элемент в хэш-таблицу."""
        hash_index = (itemset[0] * 10 + itemset[1]) % len(self.hash_table)
        self.hash_table[hash_index] += 1

    def get_itemset_count(self, itemset):
        """Получить количество элементов для данного элемента из хэш-таблицы."""
        hash_index = (itemset[0] * 10 + itemset[1]) % len(self.hash_table)
        return self.hash_table[hash_index]


def generateCandidateItemsets(level_k, level_frequent_itemsets):
    """Генерация и сокращение наборов элементов-кандидатов для следующего уровня с использованием часто используемых наборов элементов текущего уровня.
    @ Параметры
    ----------
    level_k : целое число
            Текущий номер уровня

    level_frequent_itemsets : список списков
            Список частых наборов предметов текущего уровня
    @ Возвращает
    -------
    список списков
            Наборы-кандидаты следующего уровня
    """
    n_frequent_itemsets = len(level_frequent_itemsets)
    candidate_frequent_itemsets = []
    for i in range(n_frequent_itemsets):
        j = i + 1
        while (j < n_frequent_itemsets) and (
            level_frequent_itemsets[i][: level_k - 1]
            == level_frequent_itemsets[j][: level_k - 1]
        ):
            candidate_itemset = (
                level_frequent_itemsets[i][: level_k - 1]
                + [level_frequent_itemsets[i][level_k - 1]]
                + [level_frequent_itemsets[j][level_k - 1]]
            )
            candidate_itemset_pass = False

            if level_k == 1:
                candidate_itemset_pass = True

            elif (level_k == 2) and (candidate_itemset[-2:] in level_frequent_itemsets):
                candidate_itemset_pass = True

            elif all(
                (list(_) + candidate_itemset[-2:]) in level_frequent_itemsets
                for _ in combinations(candidate_itemset[:-2], level_k - 2)
            ):
                candidate_itemset_pass = True

            if candidate_itemset_pass:
                candidate_frequent_itemsets.append(candidate_itemset)

            j += 1

    return candidate_frequent_itemsets


def aprioriAlgorithm(transactions, min_support_count):
    """Извлечение часто встречающихся наборов элементов из транзакций с использованием априорного алгоритма
    @ Параметры
    ----------
    транзакции : список наборов
            Список транзакций

    min_support_count : целое число
            Минимальное количество поддержки для набора элементов, которое считается частым
    @ Возвращает
    -------
    список наборов
             Список частых наборов элементов, извлеченных из транзакций
    """

    # Извлечь список элементов в транзакциях
    items = set()
    for transaction in transactions:
        items.update(transaction)
    items = sorted(list(items))

    # Список частых наборов в транзакции
    frequent_itemsets = []

    level_k = 1  # Текущий номер уровня

    level_frequent_itemsets = []  # Level 0: частые наборы предметов
    candidate_frequent_itemsets = [
        [item] for item in items
    ]  # Level 1: наборы элементов-кандидатов

    # Инициализировать хеш-таблицу
    hash_tb = HashTable(7)

    while candidate_frequent_itemsets:
        # Подсчитаем поддержку всех возможных часто используемых наборов элементов и удалим транзакции, используя сокращение транзакций
        candidate_freq_itemsets_cnts = [0] * len(candidate_frequent_itemsets)

        for transaction in transactions:
            # добавить количество наборов элементов размера 2 в хеш-таблицу
            if level_k == 1:
                for itemset in combinations(transaction, 2):
                    hash_tb.add_itemset(itemset)

            for i, itemset in enumerate(candidate_frequent_itemsets):
                if all(_item in transaction for _item in itemset):
                    candidate_freq_itemsets_cnts[i] += 1

        # Сгенерируем часто встречающиеся наборы элементов уровня k путем сокращения нечастых наборов элементов
        level_frequent_itemsets = [
            itemset
            for itemset, support in zip(
                candidate_frequent_itemsets, candidate_freq_itemsets_cnts
            )
            if support >= min_support_count
        ]
        frequent_itemsets.extend(
            [
                set(level_frequent_itemset)
                for level_frequent_itemset in level_frequent_itemsets
            ]
        )

        # Сгенерируйте кандидатов Ck+1 из Ck (используя генерацию и обрезку)
        candidate_frequent_itemsets = generateCandidateItemsets(
            level_k, level_frequent_itemsets
        )
        level_k += 1

        # Обрежем C_2, используя хеш-таблицу, сгенерированную во время L_1
        if level_k == 2:
            for itemset in candidate_frequent_itemsets:
                if hash_tb.get_itemset_count(itemset) < min_support_count:
                    print("Урезанный набор элементов", itemset)
                    candidate_frequent_itemsets.remove(itemset)

    return frequent_itemsets


""" Load the standard market basket dataset from datasets module """
""" 
Загрузим данные
def load_market_basket():
        import pandas as pd
        # Данные https://www.kaggle.com/datasets/devchauhan1/market-basket-optimisationcsv
        dataset = pd.read_csv('./data/market_basket.csv', header = None)
        # Preprocessing the dataset
        transactions = []
        for index, data in dataset.iterrows():
                transaction = [len(el) for el in pd.Series.tolist(data[~pd.isnull(data)])]
                transactions.append(set(transaction))
        return transactions

transactions = load_market_basket()
min_support_count = 100
verbose = False """

""" Пример данных, предложенный - Arun K. Pujari """
transactions = [
    {1, 2, 5},
    {2, 4},
    {2, 3},
    {1, 2, 4},
    {1, 3},
    {2, 3},
    {1, 3},
    {1, 2, 3, 5},
    {1, 2, 3},
    {1, 2},
    {1, 3, 5},
]

min_support_count = 3

# Сгенерируйте список всех часто используемых наборов элементов с помощью сокращения транзакций Apriori
frequent_itemsets = aprioriAlgorithm(transactions, min_support_count)

print(
    "\nЧАСТЫЕ НАБОРЫ ЭЛЕМЕНТОВ (минимальное количество поддержки = {})".format(
        min_support_count
    )
)
for frequent_itemset in frequent_itemsets:
    print(frequent_itemset)
# Out:
# Урезанный набор элементов [2, 5]
#
# ЧАСТЫЕ НАБОРЫ ЭЛЕМЕНТОВ (минимальное количество поддержки = 3)
# {1}
# {2}
# {3}
# {5}
# {1, 2}
# {1, 3}
# {1, 5}
# {2, 3}
